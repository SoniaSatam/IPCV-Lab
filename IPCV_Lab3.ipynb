# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# # Contrast Stretching

# %%
# Function to map each intensity level to output intensity level.
def pixelVal(pix, a, b, l, m, n):
  v = l*a
  w = m*(b-a) + v
  if (0 <= pix and pix <= a):
      return (v / a)*pix
  elif (a < pix and pix <= b):
      return ((w - v)/(b - a)) * (pix - a) + v
  else:
      return ((255 - w)/(255 - b)) * (pix - b) + w

# %%
img = cv2.imread('/content/star-4701122_640.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x426>

# %%
img = cv2.imread('/content/star-4701122_640.jpg', 0)
a = 60
b = 140
l_1 = 0.1
m_1 = 1.5
n_1 = 0.6

# %%
plt.imshow(img, cmap='gray')

# %%
img.min()
# Out:
# 0

# %%
img.max()
# Out:
# 255

# %%
pixelVal_vec = np.vectorize(pixelVal)

# %%
contrast_stretched_1 = pixelVal_vec(img, a, b, l_1, m_1, n_1)

# %%
plt.imshow(contrast_stretched_1, cmap='gray')

# %%
contrast_stretched_1.min()
# Out:
# 0.0

# %%
a = 60
b = 140
l_2 = 1.5
m_2 = 0.5
n_2 = 2

# %%
contrast_stretched_2 = pixelVal_vec(img, a, b, l_2, m_2, n_2)
plt.imshow(contrast_stretched_2, cmap='gray')

# %%
contrast_stretched_2.min()
# Out:
# 0.0

# %% [markdown]
# # Log Transformation

# %%
c = 150
log_transformed = c*np.log(img + 1)

log_transformed = np.array(log_transformed, dtype = np.uint8)

plt.imshow(log_transformed, cmap='gray')
# Out:
# <ipython-input-14-012fe7bb06f9>:2: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c*np.log(img + 1)
# <ipython-input-14-012fe7bb06f9>:4: RuntimeWarning: invalid value encountered in cast
#   log_transformed = np.array(log_transformed, dtype = np.uint8)

# %% [markdown]
# # Power Law Transformation

# %%
gamma_1 = 0.2
gamma_2 = 2.5

power_transformed_1 = img**gamma_1
plt.imshow(power_transformed_1, cmap='gray')

# %%
power_transformed_2 = img**gamma_2
plt.imshow(power_transformed_2, cmap='gray')
